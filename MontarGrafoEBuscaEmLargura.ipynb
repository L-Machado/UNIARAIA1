# %% [markdown]
# <a href="https://colab.research.google.com/github/L-Machado/UNIARAIA1/blob/main/MontarGrafoEBuscaEmLargura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
def criar_grafo_exemplo():
    G = nx.Graph()

    # Adiciona nós
    G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"])

    # Adiciona arestas
    G.add_edges_from([("A", "C"), ("C", "D"), ("B", "A"), ("D", "E"), ("B", "E"), ("E", "H"), ("A", "G"),
                      ("F", "G"), ("G", "H"), ("H", "I"), ("I", "J"), ("J", "F"), ("F", "B"),
                      ("C", "F"), ("B", "D"), ("G", "I")])

    return G

# %%
def desenhar_grafo(grafo):
    pos = nx.spring_layout(grafo)  # Define a posição dos nós
    nx.draw(grafo, pos, with_labels=True, font_weight='bold', node_size=700, node_color='skyblue', font_size=10)
    plt.show()

# %%
grafo_exemplo = criar_grafo_exemplo()

# %%
desenhar_grafo(grafo_exemplo)

# %%
from collections import deque

# %%
def busca_largura(grafo, inicio, objetivo):
    fila = deque([(inicio, [inicio])])
    print(str(fila))

    while fila:
        (vertice, caminho) = fila.popleft()
        print("vertice: " + str(vertice))
        print("caminho: " + str(caminho))
        for vizinho in grafo[vertice]:
            print("vizinho: " + str(vizinho))
            if vizinho not in caminho:
                if vizinho == objetivo:
                    return caminho + [vizinho]
                else:
                    fila.append((vizinho, caminho + [vizinho]))

# %%
fila = deque([('A', ['A'])])
print(str(fila))
(vertice, caminho) = fila.popleft()
print(str((vertice, caminho)))
# Out:
# deque([('A', ['A'])])
# ('A', ['A'])

# %%
# Seu grafo
grafo_exemplo = {
    'A': ['C', 'B', 'G'],
    'B': ['A', 'E', 'D', 'F'],
    'C': ['A', 'F', 'G'],
    'D': ['B', 'E'],
    'E': ['B', 'D', 'H'],
    'F': ['C', 'B'],
    'G': ['C', 'I'],
    'H': ['E'],
    'I': ['G', 'J'],
    'J': ['I']
}

# %%
caminho = busca_largura(grafo_exemplo, 'A', 'H')
if caminho:
    print("Caminho encontrado:", caminho)
else:
    print("Não foi encontrado um caminho entre os nós especificados.")
# Out:
# deque([('A', ['A'])])
# vertice: A
# caminho: ['A']
# vizinho: C
# vizinho: B
# vizinho: G
# vertice: C
# caminho: ['A', 'C']
# vizinho: A
# vizinho: F
# vizinho: G
# vertice: B
# caminho: ['A', 'B']
# vizinho: A
# vizinho: E
# vizinho: D
# vizinho: F
# vertice: G
# caminho: ['A', 'G']
# vizinho: C
# vizinho: I
# vertice: F
# caminho: ['A', 'C', 'F']
# vizinho: C
# vizinho: B
# vertice: G
# caminho: ['A', 'C', 'G']
# vizinho: C
# vizinho: I
# vertice: E
# caminho: ['A', 'B', 'E']
# vizinho: B
# vizinho: D
# vizinho: H
# Caminho encontrado: ['A', 'B', 'E', 'H']
